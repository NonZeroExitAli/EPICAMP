# %%
import requests
from bs4 import BeautifulSoup
import warnings


BASE_URL = "http://bioinformatics.cs.ntou.edu.tw/adam"

def get_more_clusters():
    """Fetch clusters from the page after clicking the 'more...' button."""
    # Access the "more..." page directly
    more_url = f"{BASE_URL}/cluster_info.php?f=more"
    response = requests.get(more_url, verify=False)
    response.raise_for_status()
    soup = BeautifulSoup(response.content, "html.parser")

    # Find cluster links on the "more..." page
    clusters = []
    for a in soup.find_all("a", href=True):
        if "search_d.php?f=cluster" in a['href']:
            clusters.append(a['href'])

    return clusters

def get_sequences(cluster_link):
    """Scrape a cluster page to extract sequence IDs and sequences."""
    url = f"{BASE_URL}/{cluster_link}"
    response = requests.get(url, verify=False)
    response.raise_for_status()
    soup = BeautifulSoup(response.content, "html.parser")

    # Extract sequences from the table
    sequences = []
    rows = soup.find_all("tr")[1:]  # Skip header row
    for row in rows:
        cells = row.find_all("td")
        if len(cells) >= 3:
            seq_id = cells[0].text.strip()
            sequence = cells[2].text.strip().replace("\n", "")
            sequences.append((seq_id, sequence))

    return sequences

def save_to_csv(data, filename="sequences.csv"):
    """Save extracted sequences to a CSV file."""
    with open(filename, "w", newline="", encoding="utf-8") as file:
        writer = csv.writer(file)
        writer.writerow(["Sequence ID", "Sequence"])  # Header
        writer.writerows(data)

def main():
    """Main script to scrape and save sequences."""
    print("Fetching clusters from the 'more...' page...")
    cluster_links = get_more_clusters()

    all_sequences = []
    for cluster_link in cluster_links:
        print(f"Processing {cluster_link}...")
        sequences = get_sequences(cluster_link)
        all_sequences.extend(sequences)

    print("Saving sequences to CSV...")
    save_to_csv(all_sequences)
    print("Done!")

if __name__ == "__main__":
    main()
# Out:
# Fetching clusters from the 'more...' page...
# Processing ./search_d.php?f=cluster,1...
# Processing ./search_d.php?f=cluster,2...
# Processing ./search_d.php?f=cluster,3...
# Processing ./search_d.php?f=cluster,4...
# Processing ./search_d.php?f=cluster,5...
# Processing ./search_d.php?f=cluster,6...
# Processing ./search_d.php?f=cluster,7...
# Processing ./search_d.php?f=cluster,8...
# Processing ./search_d.php?f=cluster,9...
# Processing ./search_d.php?f=cluster,10...
# Processing ./search_d.php?f=cluster,11...
# Processing ./search_d.php?f=cluster,12...
# Processing ./search_d.php?f=cluster,13...
# Processing ./search_d.php?f=cluster,14...
# Processing ./search_d.php?f=cluster,15...
# Processing ./search_d.php?f=cluster,16...
# Processing ./search_d.php?f=cluster,17...
# Processing ./search_d.php?f=cluster,18...
# Processing ./search_d.php?f=cluster,19...
# Processing ./search_d.php?f=cluster,20...
# Processing ./search_d.php?f=cluster,21...
# Processing ./search_d.php?f=cluster,22...
# Processing ./search_d.php?f=cluster,23...
# Processing ./search_d.php?f=cluster,24...
# Processing ./search_d.php?f=cluster,25...
# Processing ./search_d.php?f=cluster,26...
# Processing ./search_d.php?f=cluster,27...
# Processing ./search_d.php?f=cluster,28...
# Processing ./search_d.php?f=cluster,29...
# Processing ./search_d.php?f=cluster,30...
# Processing ./search_d.php?f=cluster,31...
# Processing ./search_d.php?f=cluster,32...
# Processing ./search_d.php?f=cluster,33...
# Processing ./search_d.php?f=cluster,34...
# Processing ./search_d.php?f=cluster,35...
# Processing ./search_d.php?f=cluster,36...
# Processing ./search_d.php?f=cluster,37...
# Processing ./search_d.php?f=cluster,38...
# Processing ./search_d.php?f=cluster,39...
# Processing ./search_d.php?f=cluster,40...
# Processing ./search_d.php?f=cluster,41...
# Processing ./search_d.php?f=cluster,42...
# Processing ./search_d.php?f=cluster,43...
# Processing ./search_d.php?f=cluster,44...
# Processing ./search_d.php?f=cluster,45...
# Processing ./search_d.php?f=cluster,46...
# Processing ./search_d.php?f=cluster,47...
# Processing ./search_d.php?f=cluster,48...
# Processing ./search_d.php?f=cluster,49...
# Processing ./search_d.php?f=cluster,50...
# Processing ./search_d.php?f=cluster,51...
# Processing ./search_d.php?f=cluster,52...
# Processing ./search_d.php?f=cluster,53...
# Processing ./search_d.php?f=cluster,54...
# Processing ./search_d.php?f=cluster,55...
# Processing ./search_d.php?f=cluster,56...
# Processing ./search_d.php?f=cluster,57...
# Processing ./search_d.php?f=cluster,58...
# Processing ./search_d.php?f=cluster,59...
# Processing ./search_d.php?f=cluster,60...
# Processing ./search_d.php?f=cluster,61...
# Processing ./search_d.php?f=cluster,62...
# Processing ./search_d.php?f=cluster,63...
# Processing ./search_d.php?f=cluster,64...
# Processing ./search_d.php?f=cluster,65...
# Processing ./search_d.php?f=cluster,66...
# Processing ./search_d.php?f=cluster,67...
# Processing ./search_d.php?f=cluster,68...
# Processing ./search_d.php?f=cluster,69...
# Processing ./search_d.php?f=cluster,70...
# Processing ./search_d.php?f=cluster,71...
# Processing ./search_d.php?f=cluster,72...
# Processing ./search_d.php?f=cluster,73...
# Processing ./search_d.php?f=cluster,74...
# Processing ./search_d.php?f=cluster,75...
# Processing ./search_d.php?f=cluster,76...
# Processing ./search_d.php?f=cluster,77...
# Processing ./search_d.php?f=cluster,78...
# Processing ./search_d.php?f=cluster,79...
# Processing ./search_d.php?f=cluster,80...
# Processing ./search_d.php?f=cluster,81...
# Processing ./search_d.php?f=cluster,82...
# Processing ./search_d.php?f=cluster,83...
# Processing ./search_d.php?f=cluster,84...
# Processing ./search_d.php?f=cluster,85...
# Processing ./search_d.php?f=cluster,86...
# Processing ./search_d.php?f=cluster,87...
# Processing ./search_d.php?f=cluster,88...
# Processing ./search_d.php?f=cluster,89...
# Processing ./search_d.php?f=cluster,90...
# Processing ./search_d.php?f=cluster,91...
# Processing ./search_d.php?f=cluster,92...
# Processing ./search_d.php?f=cluster,93...
# Processing ./search_d.php?f=cluster,94...
# Processing ./search_d.php?f=cluster,95...
# Processing ./search_d.php?f=cluster,96...
# Processing ./search_d.php?f=cluster,97...
# Processing ./search_d.php?f=cluster,98...
# Processing ./search_d.php?f=cluster,99...
# Processing ./search_d.php?f=cluster,100...
# Processing ./search_d.php?f=cluster,101...
# Processing ./search_d.php?f=cluster,102...
# Processing ./search_d.php?f=cluster,103...
# Processing ./search_d.php?f=cluster,104...
# Processing ./search_d.php?f=cluster,105...
# Processing ./search_d.php?f=cluster,106...
# Processing ./search_d.php?f=cluster,107...
# Processing ./search_d.php?f=cluster,108...
# Processing ./search_d.php?f=cluster,109...
# Processing ./search_d.php?f=cluster,110...
# Processing ./search_d.php?f=cluster,111...
# Processing ./search_d.php?f=cluster,112...
# Processing ./search_d.php?f=cluster,113...
# Processing ./search_d.php?f=cluster,114...
# Processing ./search_d.php?f=cluster,115...
# Processing ./search_d.php?f=cluster,116...
# Processing ./search_d.php?f=cluster,117...
# Processing ./search_d.php?f=cluster,118...
# Processing ./search_d.php?f=cluster,119...
# Processing ./search_d.php?f=cluster,120...
# Processing ./search_d.php?f=cluster,121...
# Processing ./search_d.php?f=cluster,122...
# Processing ./search_d.php?f=cluster,123...
# Processing ./search_d.php?f=cluster,124...
# Processing ./search_d.php?f=cluster,125...
# Processing ./search_d.php?f=cluster,126...
# Processing ./search_d.php?f=cluster,127...
# Processing ./search_d.php?f=cluster,128...
# Processing ./search_d.php?f=cluster,129...
# Processing ./search_d.php?f=cluster,130...
# Processing ./search_d.php?f=cluster,131...
# Processing ./search_d.php?f=cluster,132...
# Processing ./search_d.php?f=cluster,133...
# Processing ./search_d.php?f=cluster,134...
# Processing ./search_d.php?f=cluster,135...
# Processing ./search_d.php?f=cluster,136...
# Processing ./search_d.php?f=cluster,137...
# Processing ./search_d.php?f=cluster,138...
# Processing ./search_d.php?f=cluster,139...
# Processing ./search_d.php?f=cluster,140...
# Processing ./search_d.php?f=cluster,141...
# Processing ./search_d.php?f=cluster,142...
# Processing ./search_d.php?f=cluster,143...
# Processing ./search_d.php?f=cluster,144...
# Processing ./search_d.php?f=cluster,145...
# Processing ./search_d.php?f=cluster,146...
# Processing ./search_d.php?f=cluster,147...
# Processing ./search_d.php?f=cluster,148...
# Processing ./search_d.php?f=cluster,149...
# Processing ./search_d.php?f=cluster,150...
# Processing ./search_d.php?f=cluster,151...
# Processing ./search_d.php?f=cluster,152...
# Processing ./search_d.php?f=cluster,153...
# Processing ./search_d.php?f=cluster,154...
# Processing ./search_d.php?f=cluster,155...
# Processing ./search_d.php?f=cluster,156...
# Processing ./search_d.php?f=cluster,157...
# Processing ./search_d.php?f=cluster,158...
# Processing ./search_d.php?f=cluster,159...
# Processing ./search_d.php?f=cluster,160...
# Processing ./search_d.php?f=cluster,161...
# Processing ./search_d.php?f=cluster,162...
# Processing ./search_d.php?f=cluster,163...
# Processing ./search_d.php?f=cluster,164...
# Processing ./search_d.php?f=cluster,165...
# Processing ./search_d.php?f=cluster,166...
# Processing ./search_d.php?f=cluster,167...
# Processing ./search_d.php?f=cluster,168...
# Processing ./search_d.php?f=cluster,169...
# Processing ./search_d.php?f=cluster,170...
# Processing ./search_d.php?f=cluster,171...
# Processing ./search_d.php?f=cluster,172...
# Processing ./search_d.php?f=cluster,173...
# Processing ./search_d.php?f=cluster,174...
# Processing ./search_d.php?f=cluster,175...
# Processing ./search_d.php?f=cluster,176...
# Processing ./search_d.php?f=cluster,177...
# Processing ./search_d.php?f=cluster,178...
# Processing ./search_d.php?f=cluster,179...
# Processing ./search_d.php?f=cluster,180...
# Processing ./search_d.php?f=cluster,181...
# Processing ./search_d.php?f=cluster,182...
# Processing ./search_d.php?f=cluster,183...
# Processing ./search_d.php?f=cluster,184...
# Processing ./search_d.php?f=cluster,185...
# Processing ./search_d.php?f=cluster,186...
# Processing ./search_d.php?f=cluster,187...
# Processing ./search_d.php?f=cluster,188...
# Processing ./search_d.php?f=cluster,189...
# Processing ./search_d.php?f=cluster,190...
# Processing ./search_d.php?f=cluster,191...
# Processing ./search_d.php?f=cluster,192...
# Processing ./search_d.php?f=cluster,193...
# Processing ./search_d.php?f=cluster,194...
# Processing ./search_d.php?f=cluster,195...
# Processing ./search_d.php?f=cluster,196...
# Processing ./search_d.php?f=cluster,197...
# Processing ./search_d.php?f=cluster,198...
# Processing ./search_d.php?f=cluster,199...
# Processing ./search_d.php?f=cluster,200...
# Processing ./search_d.php?f=cluster,201...
# Processing ./search_d.php?f=cluster,202...
# Processing ./search_d.php?f=cluster,203...
# Processing ./search_d.php?f=cluster,204...
# Processing ./search_d.php?f=cluster,205...
# Processing ./search_d.php?f=cluster,206...
# Processing ./search_d.php?f=cluster,207...
# Processing ./search_d.php?f=cluster,208...
# Processing ./search_d.php?f=cluster,209...
# Processing ./search_d.php?f=cluster,210...
# Processing ./search_d.php?f=cluster,211...
# Processing ./search_d.php?f=cluster,212...
# Processing ./search_d.php?f=cluster,213...
# Processing ./search_d.php?f=cluster,214...
# Processing ./search_d.php?f=cluster,215...
# Processing ./search_d.php?f=cluster,216...
# Processing ./search_d.php?f=cluster,217...
# Processing ./search_d.php?f=cluster,218...
# Processing ./search_d.php?f=cluster,219...
# Processing ./search_d.php?f=cluster,220...
# Processing ./search_d.php?f=cluster,221...
# Processing ./search_d.php?f=cluster,222...
# Processing ./search_d.php?f=cluster,223...
# Processing ./search_d.php?f=cluster,224...
# Processing ./search_d.php?f=cluster,225...
# Saving sequences to CSV...
# Done!

# %%
def count_total_sequences(file_path):
    """
    Reads a file and counts the total number of sequences from the '#SEQ' column.

    Args:
        file_path (str): Path to the input file.

    Returns:
        int: Total number of sequences across all clusters.
    """
    total_sequences = 0

    try:
        with open(file_path, 'r') as file:
            for line in file:
                # Check if the line contains a numeric value for sequences
                stripped_line = line.strip()
                if stripped_line.isdigit():  # Assuming the sequence number is on its own line
                    total_sequences += int(stripped_line)
    except FileNotFoundError:
        print(f"Error: The file {file_path} does not exist.")
    except Exception as e:
        print(f"An error occurred: {e}")

    return total_sequences

# Uncomment below to test the function with a file path
file_path = "ADAM_text.txt"
print(f"Total Sequences: {count_total_sequences(file_path)}")
# Out:
# Total Sequences: 2951

# %%
import pandas as pd

# Load the Excel file
file_path = 'sequences.csv'  # Replace with your file path
df = pd.read_csv(file_path)

# Identify rows to keep (either the first row or rows not containing 'sequence')
filtered_df = df[~df.apply(lambda row: row.astype(str).str.contains('sequence', case=False).any(), axis=1)]
filtered_df = pd.concat([df.iloc[[0]], filtered_df])  # Retain the first row

# Save the cleaned file
filtered_df.to_csv('cleaned_file.csv', index=False)
